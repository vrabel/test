# %% [markdown]
# # One Compartment Model
# Simulate the dynamic behavior of a antibiotic injection model
#
# (note: figure out LaTEX)
# $$ V\frac{dC}{dt} = u(t) - QC $$
# $$ \frac{dC}{dt} = u(t)/V -(Q/V)C$$

# %%
# %matplotlib inline  
# percent sign means instructions to jupyter on what to do with commands from certain library


import numpy as np                  # numerical library equivalent of matlab
import matplotlib.pyplot as plt     #plotting library modeled after plotting library in matlab
from scipy.integrate import odeint  #import only odeint (ordinary diff eqn) from entire library of scipy.integrate

# %%
# parameter values
V = 4       # liters      plasma volume
Q = 0.5     # liters/hour
Cint = 16   # mg/liter    initial condition
MIC = 5     # mg/liter
MBC = 8     # mg/liter

# differential equation
def u(t):
    return 0

def Cderiv(C,t):
    return u(t)/V - (Q/V)*C

# simulation
t = np.linspace(0,24,1000) # linspace is part of numpy library
sol = odeint(Cderiv, Cint, t)  # (name of derive, initial cond, variable of integration)
plt.plot(t,sol)
plt.xlabel('Time [hrs]')
plt.ylabel('Conc. [mg/liter]')
plt.grid()

# visualization

# %%
# parameter values
V = 4       # liters      plasma volume
Q = 0.5     # liters/hour
Cint = 0   # mg/liter    initial condition
MIC = 5     # mg/liter
MBC = 8     # mg/liter

# differential equation
tdose = 3  # dosing period

def u(t):
    if (t <= tdose):
        return 64/tdose
    else:
        return 0

def Cderiv(C,t):
    return u(t)/V - (Q/V)*C

# simulation
t = np.linspace(0,24,1000) # linspace is part of numpy library
sol = odeint(Cderiv, Cint, t)  # (name of derive, initial cond, variable of integration)
plt.plot(t,sol)
plt.xlabel('Time [hrs]')
plt.ylabel('Conc. [mg/liter]')
plt.grid()

# visualization

# %%
j=8
i=0

#for i==[0,1,2,3]:
 #   return j = j+1

print(j)
# Out:
# Object `for` not found.
# 8

# %%
# parameter values
V = 4          # liters
Q = 0.5        # liters/hour
Cinitial = 0   # mg/liter
MIC = 5        # mg/liter
MBC = 8        # mg/liter

# parameter values
td = 0.5         # length hours
#tdose = 9.5        # dosing period
Udose = 64       # mg


for tdose >= 8, <= 10:
# function defintion
def u(t):
    if t % tdose <= dt:
        return Udose/td
    else:
        return 0

# differential equation
def Cderiv(C,t):
    return u(t)/V - (Q/V)*C
    
    if sol >= MIC:
    return 

# simulation
t = np.linspace(0,96,1000)
sol = odeint(Cderiv, Cinitial, t, tcrit=t)
# Out:
#   File "<ipython-input-4-f56e82315cd6>", line 14
#     for tdose >= 8, <= 10:
#                ^
# SyntaxError: invalid syntax

# %%
for x in range(1, 11):
    for y in range(1, 11):
        print (x, y, x*y)
# Out:
# 1 1 1
# 1 2 2
# 1 3 3
# 1 4 4
# 1 5 5
# 1 6 6
# 1 7 7
# 1 8 8
# 1 9 9
# 1 10 10
# 2 1 2
# 2 2 4
# 2 3 6
# 2 4 8
# 2 5 10
# 2 6 12
# 2 7 14
# 2 8 16
# 2 9 18
# 2 10 20
# 3 1 3
# 3 2 6
# 3 3 9
# 3 4 12
# 3 5 15
# 3 6 18
# 3 7 21
# 3 8 24
# 3 9 27
# 3 10 30
# 4 1 4
# 4 2 8
# 4 3 12
# 4 4 16
# 4 5 20
# 4 6 24
# 4 7 28
# 4 8 32
# 4 9 36
# 4 10 40
# 5 1 5
# 5 2 10
# 5 3 15
# 5 4 20
# 5 5 25
# 5 6 30
# 5 7 35
# 5 8 40
# 5 9 45
# 5 10 50
# 6 1 6
# 6 2 12
# 6 3 18
# 6 4 24
# 6 5 30
# 6 6 36
# 6 7 42
# 6 8 48
# 6 9 54
# 6 10 60
# 7 1 7
# 7 2 14
# 7 3 21
# 7 4 28
# 7 5 35
# 7 6 42
# 7 7 49
# 7 8 56
# 7 9 63
# 7 10 70
# 8 1 8
# 8 2 16
# 8 3 24
# 8 4 32
# 8 5 40
# 8 6 48
# 8 7 56
# 8 8 64
# 8 9 72
# 8 10 80
# 9 1 9
# 9 2 18
# 9 3 27
# 9 4 36
# 9 5 45
# 9 6 54
# 9 7 63
# 9 8 72
# 9 9 81
# 9 10 90
# 10 1 10
# 10 2 20
# 10 3 30
# 10 4 40
# 10 5 50
# 10 6 60
# 10 7 70
# 10 8 80
# 10 9 90
# 10 10 100

# %%
range?
